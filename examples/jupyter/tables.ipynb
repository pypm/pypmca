# %% [markdown]
# # Examining a pyPM model with tables
#
# In pypm/tools/tables, methods are provided to show the model definition in table format
#
# * connectors, shown in order of their execution for each cycle: print(table.connector_table(model, width=120)
# * populations: print(table.population_table(model, width=120)
# * parameters: print(table.parameter_table(model, width=120)
# * modifiers: print(table.modifier_table(model, width=120)
# * injectors: print(table.injector_table(model, width=120)
# * delays: print(table.delay_table(model, width=120)
# * variable parameters: print(table.variable_parameter_table(model, width=120)

# %%
from pathlib import Path
from pypm import Model
from pypm.tools import table

# %%
example_dir = Path('..').resolve()
path_model_2 = example_dir / 'ref_model_2.pypm'
ref_model_2 = Model.open_file(path_model_2)

width = 104

# %%
print(table.connector_table(ref_model_2, width))
# Out:
# Connector            Type         From                To                  Parameters              Values
#                                   (populations)       (populations)
# ========================================================================================================
# infection cycle      Multiplier   susceptible         infected            alpha                    0.385
#                                   contagious
#                                   total
# --------------------------------------------------------------------------------------------------------
# infected to          Propagator   infected            contagious          cont_frac                0.900
# contagious                                                                cont_delay_mean          2.000
#                                                                           cont_delay_sigma         1.000
# --------------------------------------------------------------------------------------------------------
# recovery             Splitter     contagious          recovered           recover_frac             0.990
#                                                       deaths              recover_delay_mea       14.000
#                                                                           n                        5.000
#                                                                           recover_delay_sig       21.000
#                                                                           ma                       5.000
#                                                                           death_delay_mean
#                                                                           death_delay_sigma
# --------------------------------------------------------------------------------------------------------
# symptoms             Splitter     contagious          contact_traced      contact_traced_fr        0.000
#                                                       symptomatic         ac                       0.900
#                                                       asymptomatic        symptomatic_frac         2.000
#                                                       recovered           contact_traced_de        1.000
#                                                                           lay_mean                 2.000
#                                                                           contact_traced_de        1.000
#                                                                           lay_sigma               12.000
#                                                                           symptomatic_delay        4.000
#                                                                           _mean
#                                                                           symptomatic_delay
#                                                                           _sigma
#                                                                           asymp_rec_delay_m
#                                                                           ean
#                                                                           asymp_rec_delay_s
#                                                                           igma
# --------------------------------------------------------------------------------------------------------
# remove               Subtractor   contagious          asymptomatic
# asymptomatic                                          recovered
# recoveries
# --------------------------------------------------------------------------------------------------------
# testing              Splitter     symptomatic         reported            reported_frac            0.800
#                                                       unreported          reported_delay_me        3.000
#                                                                           an                       1.000
#                                                                           reported_delay_si       12.000
#                                                                           gma                      4.000
#                                                                           unrep_rec_delay_m
#                                                                           ean
#                                                                           unrep_rec_delay_s
#                                                                           igma
# --------------------------------------------------------------------------------------------------------
# report               Adder        contact_traced      reported
# contact_traced
# --------------------------------------------------------------------------------------------------------
# remove those         Subtractor   contagious          reported
# reported
# --------------------------------------------------------------------------------------------------------
# remove unreported    Subtractor   contagious          unreported
# recoveries
# --------------------------------------------------------------------------------------------------------
# symptomatic to       Propagator   symptomatic         non_icu_hospitali   non_icu_hosp_frac        0.200
# non_icu hospital                                      zed                 non_icu_hosp_dela       12.000
#                                                                           y_mean                   3.000
#                                                                           non_icu_hosp_dela
#                                                                           y_sigma
# --------------------------------------------------------------------------------------------------------
# non_icu hospital     Propagator   non_icu_hospitali   non_icu_rel         release_frac             1.000
# to released                       zed                                     non_icu_rel_delay       10.000
#                                                                           _mean                    3.000
#                                                                           non_icu_rel_delay
#                                                                           _sigma
# --------------------------------------------------------------------------------------------------------
# symptomatic to icu   Propagator   symptomatic         icu admissions      icu_frac                 0.100
#                                                                           to_icu_delay_mean       14.000
#                                                                           to_icu_delay_sigm        1.000
#                                                                           a
# --------------------------------------------------------------------------------------------------------
# ventilator           Splitter     icu admissions      ventilated          icu_frac                 0.100
#                                                       non_ventilated_re   to_icu_delay_mean       14.000
#                                                       l                   to_icu_delay_sigm        1.000
#                                                                           a                       14.000
#                                                                           non_vent_icu_dela        5.000
#                                                                           y_mean
#                                                                           non_vent_icu_dela
#                                                                           y_sigma
# --------------------------------------------------------------------------------------------------------
# ventilator to        Propagator   ventilated          ventilated_rel      vent_frac                1.000
# released                                                                  in_vent_delay_mea       10.000
#                                                                           n                        5.000
#                                                                           in_vent_delay_sig
#                                                                           ma
# --------------------------------------------------------------------------------------------------------
# include non_icu in   Adder        non_icu_hospitali   hospitalized
# hospitalized                      zed
# --------------------------------------------------------------------------------------------------------
# include icu in       Adder        icu admissions      hospitalized
# hospitalized
# --------------------------------------------------------------------------------------------------------
# copy                 Adder        hospitalized        in_hospital
# hospitalizations
# --------------------------------------------------------------------------------------------------------
# copy icu             Adder        icu admissions      in_icu
# admissions
# --------------------------------------------------------------------------------------------------------
# copy ventilator      Adder        ventilated          on_ventilator
# admissions
# --------------------------------------------------------------------------------------------------------
# remove non-ICU       Subtractor   in_hospital         non_icu_rel
# released
# --------------------------------------------------------------------------------------------------------
# remove non-vent      Subtractor   in_icu              non_ventilated_re
# released from icu                                     l
# --------------------------------------------------------------------------------------------------------
# remove non-vent      Subtractor   in_hospital         non_ventilated_re
# released from                                         l
# hospital
# --------------------------------------------------------------------------------------------------------
# remove vent          Subtractor   on_ventilator       ventilated_rel
# released from
# on_ventilator
# --------------------------------------------------------------------------------------------------------
# remove vent          Subtractor   in_icu              ventilated_rel
# released from icu
# --------------------------------------------------------------------------------------------------------
# remove vent          Subtractor   in_hospital         ventilated_rel
# released from
# hospital
# --------------------------------------------------------------------------------------------------------
# subtract deaths      Subtractor   total               deaths
# from total
# --------------------------------------------------------------------------------------------------------
# subtract infected    Subtractor   susceptible         infected
# from susceptible
# --------------------------------------------------------------------------------------------------------
# outbreaks to         Propagator   outbreaks           infected            outbreak_frac            1.000
# infected                                                                  outbreak_delay_me        7.000
#                                                                           an                       1.000
#                                                                           outbreak_delay_si
#                                                                           gma

# %%
print(table.population_table(ref_model_2, width))
# Out:
# Population               Description                                             Parameter   Start value
# ========================================================================================================
# susceptible              number of people who could become infected              N_0         5000000
# --------------------------------------------------------------------------------------------------------
# contagious               number of people that can cause someone to become       cont_0      55
#                          infected
# --------------------------------------------------------------------------------------------------------
# total                    total population of the region                          N_0         5000000
# --------------------------------------------------------------------------------------------------------
# infected                 total number of people ever infected                                0
# --------------------------------------------------------------------------------------------------------
# recovered                People who have recovered from the illness and are                  0
#                          therefore no longer susceptible
# --------------------------------------------------------------------------------------------------------
# deaths                   people who have died from the illness                               0
# --------------------------------------------------------------------------------------------------------
# contact_traced           People identified through contact tracing                           0
# --------------------------------------------------------------------------------------------------------
# symptomatic              People who have shown symptoms                                      0
# --------------------------------------------------------------------------------------------------------
# asymptomatic recovered   People who have not shown symptoms                                  0
# --------------------------------------------------------------------------------------------------------
# reported                 Symptomatic people who received a positive test                     0
#                          report
# --------------------------------------------------------------------------------------------------------
# unreported               Symptomatic people who do not receive a positive test               0
#                          result
# --------------------------------------------------------------------------------------------------------
# non_icu_hospitalized     Total non_icu hospitalization cases                                 0
# --------------------------------------------------------------------------------------------------------
# non_icu_rel              Hospitalized not needing ICU and released                           0
# --------------------------------------------------------------------------------------------------------
# icu admissions           People admitted to ICU                                              0
# --------------------------------------------------------------------------------------------------------
# ventilated               People who received ICU ventilator                                  0
# --------------------------------------------------------------------------------------------------------
# non_ventilated_rel       ICU non-vent released                                               0
# --------------------------------------------------------------------------------------------------------
# ventilated_rel           ICU ventilated released                                             0
# --------------------------------------------------------------------------------------------------------
# hospitalized             Total hospitalization cases                                         0
# --------------------------------------------------------------------------------------------------------
# in_hospital              People currently in hospital                                        0
# --------------------------------------------------------------------------------------------------------
# in_icu                   People currently in ICU                                             0
# --------------------------------------------------------------------------------------------------------
# on_ventilator            People currently on ICU ventilator                                  0
# --------------------------------------------------------------------------------------------------------
# outbreaks                Infection outbreaks                                                 0

# %%
print(table.parameter_table(ref_model_2, width))
# Out:
# Parameter                    Description                            min     max        Init      Value
# ========================================================================================================
# N_0                          Population of the region at t0         5000    50000000   5000000   5000000
# --------------------------------------------------------------------------------------------------------
# alpha                        mean number of people that a           0       2          0.385     0.385
#                              contagious person infects per day
# --------------------------------------------------------------------------------------------------------
# alpha_0                      initial transmission rate              0       2          0.385     0.385
# --------------------------------------------------------------------------------------------------------
# alpha_1                      transmission rate after 1st            0       2          0.062     0.062
#                              transition
# --------------------------------------------------------------------------------------------------------
# alpha_2                      transmission rate after 2nd            0       2          0.062     0.062
#                              transition
# --------------------------------------------------------------------------------------------------------
# alpha_3                      transmission rate after 3nd            0       2          0.062     0.062
#                              transition
# --------------------------------------------------------------------------------------------------------
# asymp_rec_delay_mean         mean time from becoming contagious     0       50         12        12
#                              to recovery (without symptoms)
# --------------------------------------------------------------------------------------------------------
# asymp_rec_delay_sigma        std dev of times from becoming         0.010   20         4         4
#                              contagious to recovery with no
#                              symptoms
# --------------------------------------------------------------------------------------------------------
# cont_0                       Number of contagious people at t0      0       5000       55        55
# --------------------------------------------------------------------------------------------------------
# cont_delay_mean              mean time from being infected to       0       50         2         2
#                              becoming contagious
# --------------------------------------------------------------------------------------------------------
# cont_delay_sigma             standard deviation of times from       0.010   20         1         1
#                              being infected to becoming
#                              contagious
# --------------------------------------------------------------------------------------------------------
# cont_frac                    fraction of infected people that       0       1          0.900     0.900
#                              become contagious
# --------------------------------------------------------------------------------------------------------
# contact_traced_delay_mean    mean time from becoming contagious     0       50         2         2
#                              to being contact traced
# --------------------------------------------------------------------------------------------------------
# contact_traced_delay_sigma   std dev of times from becoming         0.010   20         1         1
#                              contagious to being contact traced
# --------------------------------------------------------------------------------------------------------
# contact_traced_frac          fraction of contagious people who      0       1          0         0
#                              are identified first through contact
#                              tracing
# --------------------------------------------------------------------------------------------------------
# death_delay_mean             mean time from infection to death      0       50         21        21
# --------------------------------------------------------------------------------------------------------
# death_delay_sigma            standard deviation of times from       0.010   20         5         5
#                              infection to death
# --------------------------------------------------------------------------------------------------------
# icu_frac                     fraction of symptomatic people who     0       1          0.100     0.100
#                              go to icu
# --------------------------------------------------------------------------------------------------------
# in_vent_delay_mean           mean time from ventilator admission    0       50         10        10
#                              to departure
# --------------------------------------------------------------------------------------------------------
# in_vent_delay_sigma          standard deviation of times from       0.010   20         5         5
#                              ventilator admission to departure
# --------------------------------------------------------------------------------------------------------
# non_icu_hosp_delay_mean      mean time from symptoms to non_icu     0       50         12        12
#                              hospitalization
# --------------------------------------------------------------------------------------------------------
# non_icu_hosp_delay_sigma     standard deviation of times from       0.010   20         3         3
#                              symptoms to non_icu hospitalization
# --------------------------------------------------------------------------------------------------------
# non_icu_hosp_frac            fraction of those with symptoms who    0       1          0.200     0.200
#                              will be admitted to non_icu hospital
# --------------------------------------------------------------------------------------------------------
# non_icu_rel_delay_mean       mean time from non_icu hospital to     0       50         10        10
#                              release
# --------------------------------------------------------------------------------------------------------
# non_icu_rel_delay_sigma      standard deviation of times from       0.010   20         3         3
#                              non_icu hospital to release
# --------------------------------------------------------------------------------------------------------
# non_vent_icu_delay_mean      mean time from non-vent icu            0       50         14        14
#                              admission to release
# --------------------------------------------------------------------------------------------------------
# non_vent_icu_delay_sigma     standard deviation of times from       0.010   20         5         5
#                              non-vent icu admission to release
# --------------------------------------------------------------------------------------------------------
# outbreak_1_number            number of infections in outbreak_1     0       50000      10        10
# --------------------------------------------------------------------------------------------------------
# outbreak_1_time              number of days since t0 when           0       100        14        14
#                              outbreak_1 established
# --------------------------------------------------------------------------------------------------------
# outbreak_2_number            number of infections in outbreak_2     0       50000      10        10
# --------------------------------------------------------------------------------------------------------
# outbreak_2_time              number of days since t0 when           0       100        21        21
#                              outbreak_2 established
# --------------------------------------------------------------------------------------------------------
# outbreak_3_number            number of infections in outbreak_3     0       50000      10        10
# --------------------------------------------------------------------------------------------------------
# outbreak_3_time              number of days since t0 when           0       100        41        41
#                              outbreak_3 established
# --------------------------------------------------------------------------------------------------------
# outbreak_delay_mean          mean delay time for outbreak           0       50         7         7
# --------------------------------------------------------------------------------------------------------
# outbreak_delay_sigma         standard deviation of loutbreak        0.010   20         1         1
#                              times
# --------------------------------------------------------------------------------------------------------
# outbreak_frac                fraction of infected in outbreak       0       1          1         1
#                              active ==1
# --------------------------------------------------------------------------------------------------------
# recover_delay_mean           mean time from infection to recovery   0       50         14        14
# --------------------------------------------------------------------------------------------------------
# recover_delay_sigma          standard deviation of times from       0.010   20         5         5
#                              infection to recovery
# --------------------------------------------------------------------------------------------------------
# recover_frac                 fraction of infected people who        0       1          0.990     0.990
#                              recover
# --------------------------------------------------------------------------------------------------------
# release_frac                 fraction for all released == 1         1       1          1         1
# --------------------------------------------------------------------------------------------------------
# reported_delay_mean          mean time from becoming symptomatic    0       50         3         3
#                              to getting positive report
# --------------------------------------------------------------------------------------------------------
# reported_delay_sigma         standard deviation of times from       0.010   20         1         1
#                              having symptoms to getting positive
#                              report
# --------------------------------------------------------------------------------------------------------
# reported_frac                fraction of symptomatic people who     0       1          0.800     0.800
#                              will receive a positive report
# --------------------------------------------------------------------------------------------------------
# symptomatic_delay_mean       mean time from becoming contagious     0       50         2         2
#                              to having symptoms
# --------------------------------------------------------------------------------------------------------
# symptomatic_delay_sigma      std dev of times from becoming         0.010   20         1         1
#                              contagious to having symptoms
# --------------------------------------------------------------------------------------------------------
# symptomatic_frac             fraction of contagious people who      0       1          0.900     0.900
#                              become symptomatic
# --------------------------------------------------------------------------------------------------------
# to_icu_delay_mean            mean time from symptoms to icu         0       50         14        14
# --------------------------------------------------------------------------------------------------------
# to_icu_delay_sigma           standard deviation of times from       0.010   20         1         1
#                              symptoms to icu
# --------------------------------------------------------------------------------------------------------
# trans_rate_1_time            number of days before 1st              0       300        16        16
#                              transmission rate change
# --------------------------------------------------------------------------------------------------------
# trans_rate_2_time            number of days before 2nd              0       300        50        50
#                              transmission rate change
# --------------------------------------------------------------------------------------------------------
# trans_rate_3_time            number of days before 3nd              0       300        70        70
#                              transmission rate change
# --------------------------------------------------------------------------------------------------------
# trans_trace_1_time           number of days before contact traced   0       300        100       100
#                              fraction changes
# --------------------------------------------------------------------------------------------------------
# trans_traced_0               initial contact traced fraction        0       1          0         0
# --------------------------------------------------------------------------------------------------------
# trans_traced_1               contact traced fraction after          0       1          0.100     0.100
#                              transition
# --------------------------------------------------------------------------------------------------------
# unrep_rec_delay_mean         mean time from symptoms to recovery    0       50         12        12
#                              for unreported
# --------------------------------------------------------------------------------------------------------
# unrep_rec_delay_sigma        standard deviation of times from       0.010   20         4         4
#                              having symptoms to recovery for
#                              unreported
# --------------------------------------------------------------------------------------------------------
# vent_frac                    fraction of those on ventialators      1       1          1         1
#                              eventually released == 1

# %%
print(table.modifier_table(ref_model_2, width))
# Out:
# Modifier         Time parameter    Time   spec       Parameter         before            after parameter
#                                                                        parameter
# ========================================================================================================
# trans_rate_1     trans_rate_1_ti   16     rel_days   alpha             alpha_0           alpha_1
#                  me
# --------------------------------------------------------------------------------------------------------
# trans_rate_2     trans_rate_2_ti   50     rel_days   alpha             alpha_1           alpha_2
#                  me
# --------------------------------------------------------------------------------------------------------
# trans_rate_3     trans_rate_3_ti   70     rel_days   alpha             alpha_2           alpha_3
#                  me
# --------------------------------------------------------------------------------------------------------
# trans_traced_1   trans_trace_1_t   100    rel_days   contact_traced_   trans_traced_0    trans_traced_1
#                  ime                                 frac

# %%
print(table.injector_table(ref_model_2, width))
# Out:
# Injector   Time parameter   Time   spec   to (Population)   Injection parameter   value
# =======================================================================================

# %%
print(table.delay_table(ref_model_2, width))
# Out:
# Connector      Con Type     Delay name     Delay Type   mean par      mean val   width par     width val
# ========================================================================================================
# infection      Multiplier   fast           fast
# cycle
# --------------------------------------------------------------------------------------------------------
# infected to    Propagator   cont_delay     norm         cont_delay_   2          cont_delay_   1
# contagious                                              mean                     sigma
# --------------------------------------------------------------------------------------------------------
# recovery       Splitter     recover_dela   norm         recover_del   14         recover_del   5
#                             y                           ay_mean                  ay_sigma
# --------------------------------------------------------------------------------------------------------
# recovery       Splitter     death_delay    norm         death_delay   21         death_delay   5
#                                                         _mean                    _sigma
# --------------------------------------------------------------------------------------------------------
# symptoms       Splitter     contact_trac   norm         contact_tra   2          contact_tra   1
#                             ed_delay                    ced_delay_m              ced_delay_s
#                                                         ean                      igma
# --------------------------------------------------------------------------------------------------------
# symptoms       Splitter     symptomatic_   norm         symptomatic   2          symptomatic   1
#                             delay                       _delay_mean              _delay_sigm
#                                                                                  a
# --------------------------------------------------------------------------------------------------------
# symptoms       Splitter     asymp_rec_de   norm         asymp_rec_d   12         asymp_rec_d   4
#                             lay                         elay_mean                elay_sigma
# --------------------------------------------------------------------------------------------------------
# testing        Splitter     reported_del   norm         reported_de   3          reported_de   1
#                             ay                          lay_mean                 lay_sigma
# --------------------------------------------------------------------------------------------------------
# testing        Splitter     unreported_d   norm         unrep_rec_d   12         unrep_rec_d   4
#                             elay                        elay_mean                elay_sigma
# --------------------------------------------------------------------------------------------------------
# symptomatic    Propagator   non_icu_hosp   norm         non_icu_hos   12         non_icu_hos   3
# to non_icu                  _delay                      p_delay_mea              p_delay_sig
# hospital                                                n                        ma
# --------------------------------------------------------------------------------------------------------
# non_icu        Propagator   non_icu_rel_   norm         non_icu_rel   10         non_icu_rel   3
# hospital to                 delay                       _delay_mean              _delay_sigm
# released                                                                         a
# --------------------------------------------------------------------------------------------------------
# symptomatic    Propagator   to_icu_delay   norm         to_icu_dela   14         to_icu_dela   1
# to icu                                                  y_mean                   y_sigma
# --------------------------------------------------------------------------------------------------------
# ventilator     Splitter     to_icu_delay   norm         to_icu_dela   14         to_icu_dela   1
#                                                         y_mean                   y_sigma
# --------------------------------------------------------------------------------------------------------
# ventilator     Splitter     in_icu_delay   norm         non_vent_ic   14         non_vent_ic   5
#                                                         u_delay_mea              u_delay_sig
#                                                         n                        ma
# --------------------------------------------------------------------------------------------------------
# ventilator     Propagator   in_vent_dela   norm         in_vent_del   10         in_vent_del   5
# to released                 y                           ay_mean                  ay_sigma
# --------------------------------------------------------------------------------------------------------
# outbreaks to   Propagator   outbreak_del   norm         outbreak_de   7          outbreak_de   1
# infected                    ay                          lay_mean                 lay_sigma

# %%
print(table.variable_parameter_table(ref_model_2, width))
# Out:
# Parameter   Description   min   max   prior   prior_mean   prior_w   mcmc_step   Init   Value
# =============================================================================================
